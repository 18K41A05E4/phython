# %%
t=str(input("Type of seat:"))
p=str(input("Payment mode:"))
if t=='circle':
  if p=='cash':
    x=((750*10)/100)
    print("Cost of ticket:",int(750-x))
  elif p=='debit':
    x=((750*5)/100)
    print("Cost of ticket:",int(750-x))
elif t=='stalls':
  if p=='cash':
    x=((625*10)/100)
    print("Cost of ticket:",int(625-x))
  elif p=='debit':
    x=((625*5)/100)
    print("Cost of ticket:",int(625-x))
elif t=='box':
  if p=='cash':
    x=((1000*10)/100)
    print("Cost of ticket:",int(1000-x))
  elif p=='debit':
    x=((1000*5)/100)
    print("Cost of ticket:",int(1000-x))
elif t=='upper class':
  if p=='cash':
    x=((850*10)/100)
    print("Cost of ticket:",int(850-x))
  elif p=='debit':
    x=((850*5)/100)
    print("Cost of ticket:",int(850-x))
# Out:
# Type of seat:stalls
# Payment mode:cash
# Cost of ticket: 562
