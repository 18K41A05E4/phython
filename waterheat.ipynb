# %%
k=int(input("Enter the water in kilograms:"))
i=int(input("Enter the initial temperature of water:"))
f=int(input("Enter the final temperature of water:"))
q = k * (f-i) * 4184
print("Energy needed to heat water from an initial to a final temperature:",q,"joules")
# Out:
# Enter the water in kilograms:5
# Enter the initial temperature of water:10
# Enter the final temperature of water:100
# Energy needed to heat water from an initial to a final temperature: 1882800 joules
