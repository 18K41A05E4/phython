# %%
"""6.  Tax CalculatorAsk  the  user  for  their  monthly  salary.  Calculate 
 whether  they  have  to  pay tax and if so, how much is that amount .
 Print the result"""

sal=int(input("Enter salary : "))
if (sal>=0) and (sal<=250000):
    tax=(sal*0)
elif (sal>250000) and (sal<=500000):
    tax=(sal*0.05)
elif (sal>500000) and (sal<=750000):
    tax=(sal*0.1)
elif (sal>750000) and (sal<=1000000):
    tax=(sal*0.15)
elif (sal>1000000) and (sal<=1250000):
    tax=(sal*0.2)
elif (sal>1250000) and (sal<=1500000):
    tax=(sal*0.25)
else:
    tax=(sal*0.3)
print("Tax to be paied : ",tax)
# Out:
# Enter salary : 1500000
# Tax to be paied :  375000.0
