# %%
"""1.  Area of Triangle :Given  the  lengths  of  three  sides  of  a  triangle,
  calculate  the  area  of the triangle. """

a=float(input("Enter length of 1st side:"))  
b=float(input("Enter length of 2nd side:"))  
c=float(input("Enter length of 3rd side:")) 
if (a+b>c):
  s=(a+b+c)/2  
  area=(s*(s-a)*(s-b)*(s-c))**0.5  
  print("The area of the triangle:",round(area,2))  
else:
  print("The triangle is not possible")
# Out:
# Enter length of 1st side:12
# Enter length of 2nd side:15
# Enter length of 3rd side:4
# The area of the triangle: 17.66
