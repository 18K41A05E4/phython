# %%
"""5.  Unique Sort problem Take  a  string  as  input  that  accepts  a  comma 
 separated  sequence  of  words as input and prints the unique words in sorted 
 form (alphanumerically).
 *Input*: orange, white, red, cyan, green, magenta, cyan, pink
 *Output*: cyan, green, magenta, orange, pink, red, white """
string=input("Enter a string: ")
s=string.split()
s.sort()
list(s)
set(s)
# Out:
# Enter a string: range, white, red, cyan, green, magenta, cyan, pink
# {'cyan,', 'green,', 'magenta,', 'pink', 'range,', 'red,', 'white,'}
