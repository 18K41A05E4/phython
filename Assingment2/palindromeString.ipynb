# %%
"""2.Take a string from end user and check if the value is palindrome or not """
s=str(input("enter a string:"))
if s==s[::-1]:
  print(s+" is palindrome")
else:
  print(s+" is not palindrome")
# Out:
# enter a string:hele
# hele is not palindrom
