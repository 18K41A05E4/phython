# %%
"""10.  Write a program that reads a date from the user and computes its immediate
 successor.The date is the format YYYY-MM-DD. So, 2020-04-15 will have the 
 successor 2020-04-16."""

yr=int(input("Enter a year : "))
if yr%400== 0:
    leap_year=True
elif yr%100==0:
    leap_year=False
elif yr%4==0:
    leap_year=True
else:
    leap_year=False
month=int(input("Enter a month between 1 to 12 : "))
if month in (1, 3, 5, 7, 8, 10, 12):
    month_length=31
elif month==2:
    if leap_year:
        month_length=29
    else:
        month_length=28
else:
    month_length=30
day=int(input("Enter a day between 1 to 31 : "))
if day<month_length:
    day+=1
else:
    day=1
    if month==12:
        month=1
        yr+=1
    else:
        month+=1
print("The immediate successor is YYYY-MM-DD : %d-%d-%d." %(yr,month,day))
# Out:
# Enter a year : 2000
# Enter a month between 1 to 12 : 12
# Enter a day between 1 to 31 : 20
# The immediate successor is YYYY-MM-DD : 2000-12-21.
