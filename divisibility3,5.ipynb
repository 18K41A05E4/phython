# %%
for i in range(1,101):
    if i%3==0:
      if i%5==0:
        print("Fizz Buzz")
    elif i%5==0:
            print("Buzz")
    elif i%3==0:
      print("Fizz")
    else:
        print(i)
# Out:
# 1
# 2
# 4
# Buzz
# 7
# 8
# Buzz
# 11
# 13
# 14
# Fizz Buzz
# 16
# 17
# 19
# Buzz
# 22
# 23
# Buzz
# 26
# 28
# 29
# Fizz Buzz
# 31
# 32
# 34
# Buzz
# 37
# 38
# Buzz
# 41
# 43
# 44
# Fizz Buzz
# 46
# 47
# 49
# Buzz
# 52
# 53
# Buzz
# 56
# 58
# 59
# Fizz Buzz
# 61
# 62
# 64
# Buzz
# 67
# 68
# Buzz
# 71
# 73
# 74
# Fizz Buzz
# 76
# 77
# 79
# Buzz
# 82
# 83
# Buzz
# 86
# 88
# 89
# Fizz Buzz
# 91
# 92
# 94
# Buzz
# 97
# 98
# Buzz
