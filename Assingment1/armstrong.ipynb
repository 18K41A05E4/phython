# %%
for i in range(1,1001):
    x=i
    c=0
    while(x>0):
        c+=1
        x=x//10
    x=i
    s=0
    while(x>0):
        s+=pow(x%10, c)
        x=x//10
    if(i == s):
        print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 153
# 370
# 371
# 407
